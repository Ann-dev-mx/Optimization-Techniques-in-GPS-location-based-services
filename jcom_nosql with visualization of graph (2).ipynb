# %%
# !pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip3 install pymongo[srv]
# Out:
# ...
#   Using cached dnspython-1.16.0-py2.py3-none-any.whl (188 kB)
# ...
#   Attempting uninstall: dnspython
#     Found existing installation: dnspython 2.0.0
#     Uninstalling dnspython-2.0.0:
#       Successfully uninstalled dnspython-2.0.0
# ...

# %%
# !pip install dnspython==2.0.0
# Out:
# ...
#   Using cached dnspython-2.0.0-py3-none-any.whl (208 kB)
# ...
#   Attempting uninstall: dnspython
#     Found existing installation: dnspython 1.16.0
#     Uninstalling dnspython-1.16.0:
#       Successfully uninstalled dnspython-1.16.0
# ...

# %%
import pymongo
from pymongo import MongoClient

cluster = MongoClient("mongodb+srv://rottyrocks:Ronaldo7&@cluster0.d692w.mongodb.net/myFirstDatabase?retryWrites=true&w=majority");

# %%
db = cluster["Jcom"]
collection = db["east"]

# %%
#import pymongo
import pprint
import matplotlib.pyplot as plt

# %%
# !pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
# !pip install openrouteservice
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pandas
# Out:
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /Users/sreyankapaul/opt/anaconda3/include/python3.8/UNKNOWN
# sysconfig: /Users/sreyankapaul/opt/anaconda3/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# ...
#      |████████████████████████████████| 10.5 MB 2.6 MB/s eta 0:00:01    |█████████████████▏              | 5.6 MB 2.6 MB/s eta 0:00:02     |███████████████████████████████▏| 10.2 MB 3.0 MB/s eta 0:00:01
# ...
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /Users/sreyankapaul/opt/anaconda3/include/python3.8/UNKNOWN
# sysconfig: /Users/sreyankapaul/opt/anaconda3/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# ...
# WARNING: You are using pip version 21.1; however, version 21.1.2 is available.
# ...

# %%
import pandas as pd

# %% [markdown]
# ## Plotting the Delivery boy to the Restaurants

# %%
ids=[]
id1=[]
for doc in collection.find( { "categories": "Delivery boy" }, { "name":1,"latitude":1,"longitude":1,"_id":0 } ):
    ids += [doc["name"],doc["latitude"],doc["longitude"]]
    
# append each document's ID to the list
  

def mul3(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

first=list(mul3(ids, 3))
#print(first)

import pandas as pd 
   
# Create the pandas DataFrame 
df1 = pd.DataFrame(first, columns = ['Name','Latitude','Longitude']) 
  
# print dataframe. 
df1
# Out:
#    Name   Latitude  Longitude
# 0   Das  33.167027 -84.403424
# 1  Ravi  33.157027 -84.423424

# %%
latitude_and_longitute_res =collection.find( { "categories":{ "$regex":"Restaurants"},"name":"Oskar Blues Taproom" }, { "name":1, "latitude":1,"longitude":1,"_id":0 } )
res = list(latitude_and_longitute_res)
pprint.pprint(res)
# Out:
# [{'latitude': 33.17, 'longitude': -84.39, 'name': 'Oskar Blues Taproom'}]

# %%
res[0]["latitude"],res[0]["longitude"]
# Out:
# (33.17, -84.39)

# %%
import openrouteservice
import folium
import pandas as pd
from folium import plugins


# m=folium.Map(location=[33.17, -84.39],zoom_start=10)
# folium.Marker([33.17, -84.39],popup='Oskar Blues Taproom',tooltip='click').add_to(m)

m1=folium.Map(location=[df1.iloc[0][1],df1.iloc[0][2]],zoom_start=10)
folium.Marker([df1.iloc[0][1],df1.iloc[0][2]],popup=df1.iloc[0][0],tooltip='click',icon=folium.Icon(color='green')).add_to(m1)

#folium.Map(location=[df1.iloc[1][1],df1.iloc[1][2]],zoom_start=10)
folium.Marker([df1.iloc[1][1],df1.iloc[1][2]],popup=df1.iloc[1][0],tooltip='click',icon=folium.Icon(color='green')).add_to(m1)

folium.Marker([res[0]["latitude"],res[0]["longitude"]],popup=res[0]["name"],tooltip='click',icon=folium.Icon(color='red')).add_to(m1)

# folium.raster_layers.TileLayer('Open Street Map').add_to(m)
# folium.raster_layers.TileLayer('CartoDB Dark_Matter').add_to(m)

# Client=openrouteservice.Client(key='5b3ce3597851110001cf6248f8eb202100d142389464c251a0593b9e')

# for index,row in df4.iterrows():
    
#     route_location = []
#     c=[[row['dest2'],row['dest1']],[row['Longitude'],row['Latitude']]]
     
#     r= Client.directions(coordinates=c, profile='driving-car', format='geojson')
  
#     for i in r["features"][0]["geometry"]["coordinates"]:
#         route_location.append(i[::-1])
#     folium.GeoJson(r,name=row['Name']).add_to(m)
  
#     folium.Marker([row['Latitude'],row['Longitude']],popup=row['Name'],icon=folium.Icon(color='purple'),tooltip='click').add_to(m)
#     plugins.AntPath(route_location).add_to(m)
    
# folium.LayerControl().add_to(m)
# folium.LayerControl(position='topright',collapsed=False).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
collection1 = db["test"]

# %%
l = list(db.test.find({"geometry":{"$nearSphere":{"$geometry":{"type":"Point","coordinates":[res[0]["longitude"],res[0]["latitude"]]},"$maxDistance":100000}},"categories":"Delivery boy"}, { "name":1, "geometry.coordinates":1,"_id":0 }).limit(1))

pprint.pprint(l)
# Out:
# [{'geometry': {'coordinates': [-84.403424, 33.167027]}, 'name': 'Das'}]

# %%
m=folium.Map(location=[l[0]["geometry"]["coordinates"][1],l[0]["geometry"]["coordinates"][0]],zoom_start=15)
folium.Marker([l[0]["geometry"]["coordinates"][1],l[0]["geometry"]["coordinates"][0]],popup=l[0]["name"],tooltip='click',icon=folium.Icon(color='green')).add_to(m)

folium.Marker([res[0]["latitude"],res[0]["longitude"]],popup=res[0]["name"],tooltip='click',icon=folium.Icon(color='red')).add_to(m)
folium.raster_layers.TileLayer('Open Street Map').add_to(m)
folium.raster_layers.TileLayer('CartoDB Dark_Matter').add_to(m)

Client=openrouteservice.Client(key='5b3ce3597851110001cf6248f8eb202100d142389464c251a0593b9e')
route_location = []
c=[[l[0]["geometry"]["coordinates"][0],l[0]["geometry"]["coordinates"][1]],[res[0]["longitude"],res[0]["latitude"]]]
r= Client.directions(coordinates=c, profile='driving-car', format='geojson')
  
for i in r["features"][0]["geometry"]["coordinates"]:
    route_location.append(i[::-1])
plugins.AntPath(route_location).add_to(m)
folium.LayerControl().add_to(m)
folium.LayerControl(position='topright',collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## Fetching from MongoDB

# %%
latitude_and_longitute_values =db.east.find( { "categories": "Customer" }, {"name":1, "latitude":1,"longitude":1,"_id":0 } )
values1 = list(latitude_and_longitute_values)
pprint.pprint(values1)
# Out:
# [{'latitude': 33.162, 'longitude': -84.4112, 'name': 'Ann mariya'},
#  {'latitude': 33.1611, 'longitude': -84.41, 'name': 'Megha Joshi'},
#  {'latitude': 33.01, 'longitude': -84.422, 'name': 'Ratnadeep pal'},
#  {'latitude': 33.11, 'longitude': -84.412, 'name': 'Vidhya'},
#  {'latitude': 33.12, 'longitude': -84.418, 'name': 'Sadheesh'},
#  {'latitude': 33.19, 'longitude': -84.4201, 'name': 'Sumar'},
#  {'latitude': 33.25, 'longitude': -84.415, 'name': 'Saratoga'}]

# %%
dataList = values1
squares=[]
key=1
for index in range(len(dataList)):
    for key in dataList[index]:
        #print(key)
        k = dataList[index][key]
        squares.append(k)
        
squares
# Out:
# ['Ann mariya',
#  33.162,
#  -84.4112,
#  'Megha Joshi',
#  33.1611,
#  -84.41,
#  'Ratnadeep pal',
#  33.01,
#  -84.422,
#  'Vidhya',
#  33.11,
#  -84.412,
#  'Sadheesh',
#  33.12,
#  -84.418,
#  'Sumar',
#  33.19,
#  -84.4201,
#  'Saratoga',
#  33.25,
#  -84.415]

# %%
i=1
new_list=[]
while i<len(squares):
  new_list.append(squares[i:i+2])
  i+=3
new_list
# Out:
# [[33.162, -84.4112],
#  [33.1611, -84.41],
#  [33.01, -84.422],
#  [33.11, -84.412],
#  [33.12, -84.418],
#  [33.19, -84.4201],
#  [33.25, -84.415]]

# %%
latitude_and_longitute_res =db.east.find( { "categories":{ "$regex":"Restaurants"} }, { "name":1, "latitude":1,"longitude":1,"_id":0 } )
res = list(latitude_and_longitute_res)
pprint.pprint(res)
# Out:
# [{'latitude': 33.17, 'longitude': -84.39, 'name': 'Oskar Blues Taproom'},
#  {'latitude': 45.5889058992,
#   'longitude': -122.5933307507,
#   'name': 'Flying Elephants at PDX'},
#  {'latitude': 49.2513423,
#   'longitude': -123.101333,
#   'name': 'Bob Likes Thai Food'},
#  {'latitude': 39.947006523, 'longitude': -82.997471, 'name': 'Boxwood Biscuit'},
#  {'latitude': 42.541155,
#   'longitude': -70.973438,
#   'name': "Mr G's Pizza & Subs"},
#  {'latitude': 28.5132647, 'longitude': -81.3747072, 'name': "Sister Honey's"},
#  {'latitude': 28.3504984,
#   'longitude': -81.542819,
#   'name': 'Everything POP Shopping & Dining'}]

# %%
data = res
squa=[]
for index in range(len(data)):
    for key in data[index]:
          k = data[index][key]
          squa.append(k)
        
squa
# Out:
# ['Oskar Blues Taproom',
#  33.17,
#  -84.39,
#  'Flying Elephants at PDX',
#  45.5889058992,
#  -122.5933307507,
#  'Bob Likes Thai Food',
#  49.2513423,
#  -123.101333,
#  'Boxwood Biscuit',
#  39.947006523,
#  -82.997471,
#  "Mr G's Pizza & Subs",
#  42.541155,
#  -70.973438,
#  "Sister Honey's",
#  28.5132647,
#  -81.3747072,
#  'Everything POP Shopping & Dining',
#  28.3504984,
#  -81.542819]

# %%
i=0
new=[]
while i<len(squa):
  new.append(squa[i:i+3])
  i+=3
new
# Out:
# [['Oskar Blues Taproom', 33.17, -84.39],
#  ['Flying Elephants at PDX', 45.5889058992, -122.5933307507],
#  ['Bob Likes Thai Food', 49.2513423, -123.101333],
#  ['Boxwood Biscuit', 39.947006523, -82.997471],
#  ["Mr G's Pizza & Subs", 42.541155, -70.973438],
#  ["Sister Honey's", 28.5132647, -81.3747072],
#  ['Everything POP Shopping & Dining', 28.3504984, -81.542819]]

# %%
values_res  = new[0]
values_res
# Out:
# ['Oskar Blues Taproom', 33.17, -84.39]

# %%
res_logi  = [values_res[1] , values_res[2]]
res_logi
# Out:
# [33.17, -84.39]

# %% [markdown]
# ## Applying Dijkstra's algo

# %%
from collections import defaultdict
from math import sqrt

def distance_between_coords(x1, y1, x2, y2):
    distance = sqrt(((x2 - x1) ** 2) + ((y2 - y1) ** 2))
    return distance

def distance_between_coords_weights(x1, y1, x2, y2,weight):
    distance = sqrt(((x2 - x1) ** 2) + ((y2 - y1) ** 2)+weight)
    return distance

def name_coords(coords):
    coord_count = 0
    for coord in coords:
        coord_count += 1
        coord.append(coord_count)
    return coords

def minimum(a, n):
   minpos = a.index(min(a))
   return minpos

def graph(coords):
    coords = name_coords(coords)
    graph = defaultdict(list)
    
    edges = {}
    for current in coords:
        for comparer in coords:
            if comparer == current:
                continue
            else:
                weight = distance_between_coords(current[0], current[1],
                                                 comparer[0], comparer[1])
                graph[current[2]].append(comparer[2])
                edges[current[2], comparer[2]] = weight
    return coords, edges


def shortest_path(node_list, edges, start):
    neighbor = 0
    unvisited = []
    visited = []
    total_weight = 0
    current_node = start
    for node in node_list:
        if node[2] == start:
            visited.append(start)
        else:
            unvisited.append(node[2])
    while unvisited:
        for index, neighbor in enumerate(unvisited):
            if index == 0:
                current_weight = edges[start, neighbor]
                current_node = neighbor
            elif edges[start, neighbor] < current_weight:
                current_weight = edges[start, neighbor]
                current_node = neighbor
        total_weight += current_weight
        unvisited.remove(current_node)
        visited.append(current_node)
    return visited, total_weight


def driver():
    coords = new_list
    coords, edges = graph(coords)
    
    shortest_path(coords, edges, 1)
    shortest_path_taken = []
    path_list = []
    shortest_path_weight = 0
    final =[]
    for index, node in enumerate(coords):
        path, weight = shortest_path(coords, edges, index + 1)
        print('--------------------------------------')
        print("Path", index + 1, "=", path)
        print("Weight =", weight*100) 
        final.append(distance_between_coords_weights(node[0],node[1],res_logi[0],res_logi[1],weight*100))
        path_list.append(path)
        if index == 0:
            shortest_path_weight = weight
            shortest_path_taken = path
        elif weight < shortest_path_weight:
            shortest_path_weight = weight
            shortest_path_taken = path
    print('--------------------------------------')
    print("The shortest path to all nodes is:", shortest_path_taken)
    
    #print("The weight of the path is:", shortest_path_weight*100)
    print("List of distances with respect to restaurant:",final)
    print("shortest path is: ", minimum(final, len(final)), "th with total weight: ",min(final))
    print("The shortest path to all nodes is:", path_list[minimum(final, len(final))])
    global original_path
    original_path = path_list[minimum(final, len(final))]

# %%
driver()
# Out:
# --------------------------------------
# Path 1 = [1, 2, 6, 5, 4, 7, 3]
# Weight = 36.589871284833706
# --------------------------------------
# Path 2 = [2, 1, 6, 5, 4, 7, 3]
# Weight = 36.574077665709915
# --------------------------------------
# Path 3 = [3, 4, 5, 2, 1, 6, 7]
# Weight = 93.46425063989707
# --------------------------------------
# Path 4 = [4, 5, 2, 1, 6, 3, 7]
# Weight = 43.57470935242931
# --------------------------------------
# Path 5 = [5, 4, 2, 1, 6, 3, 7]
# Weight = 40.62189765982895
# --------------------------------------
# Path 6 = [6, 1, 2, 7, 5, 4, 3]
# Weight = 45.06613819545166
# --------------------------------------
# Path 7 = [7, 6, 1, 2, 5, 4, 3]
# Weight = 74.7507675128794
# --------------------------------------
# The shortest path to all nodes is: [2, 1, 6, 5, 4, 7, 3]
# ...

# %%
original_path
# Out:
# [2, 1, 6, 5, 4, 7, 3]

# %%
#We are inserting Restaurant in the starting

original_path.insert(0,-1)
original_path
# Out:
# [-1, 2, 1, 6, 5, 4, 7, 3]

# %%
i=0
new_list=[[]]
while i<len(squares):
  new_list.append(squares[i:i+3])
  i+=3
new_list
# Out:
# [[],
#  ['Ann mariya', 33.162, -84.4112],
#  ['Megha Joshi', 33.1611, -84.41],
#  ['Ratnadeep pal', 33.01, -84.422],
#  ['Vidhya', 33.11, -84.412],
#  ['Sadheesh', 33.12, -84.418],
#  ['Sumar', 33.19, -84.4201],
#  ['Saratoga', 33.25, -84.415]]

# %%
mapping = {-1:[values_res[1],values_res[2],values_res[0]],
            1:[new_list[original_path[1]][1],new_list[original_path[1]][2],new_list[original_path[1]][0]],
            2:[new_list[original_path[2]][1],new_list[original_path[2]][2],new_list[original_path[2]][0]],
            3:[new_list[original_path[3]][1],new_list[original_path[3]][2],new_list[original_path[3]][0]],
            4:[new_list[original_path[4]][1],new_list[original_path[4]][2],new_list[original_path[4]][0]],
            5:[new_list[original_path[5]][1],new_list[original_path[5]][2],new_list[original_path[5]][0]],
            6:[new_list[original_path[6]][1],new_list[original_path[6]][2],new_list[original_path[6]][0]],
            7:[new_list[original_path[7]][1],new_list[original_path[7]][2],new_list[original_path[7]][0]]}
mapping
# Out:
# {-1: [33.17, -84.39, 'Oskar Blues Taproom'],
#  1: [33.1611, -84.41, 'Megha Joshi'],
#  2: [33.162, -84.4112, 'Ann mariya'],
#  3: [33.19, -84.4201, 'Sumar'],
#  4: [33.12, -84.418, 'Sadheesh'],
#  5: [33.11, -84.412, 'Vidhya'],
#  6: [33.25, -84.415, 'Saratoga'],
#  7: [33.01, -84.422, 'Ratnadeep pal']}

# %%
data = {"Name":[mapping[[-1][0]][2],mapping[[1][0]][2],mapping[[2][0]][2],mapping[[3][0]][2],
                mapping[[4][0]][2],mapping[[5][0]][2],mapping[[6][0]][2],mapping[[7][0]][2]],
        "Latitude":[mapping[[-1][0]][0],mapping[[1][0]][0],mapping[[2][0]][0],mapping[[3][0]][0],
                    mapping[[4][0]][0],mapping[[5][0]][0],mapping[[6][0]][0],mapping[[7][0]][0]],
         "Longitude":[mapping[[-1][0]][1],mapping[[1][0]][1],mapping[[2][0]][1],mapping[[3][0]][1],
                     mapping[[4][0]][1],mapping[[5][0]][1],mapping[[6][0]][1],mapping[[7][0]][1]]
        
        }
data
# Out:
# {'Name': ['Oskar Blues Taproom',
#   'Megha Joshi',
#   'Ann mariya',
#   'Sumar',
#   'Sadheesh',
#   'Vidhya',
#   'Saratoga',
#   'Ratnadeep pal'],
#  'Latitude': [33.17, 33.1611, 33.162, 33.19, 33.12, 33.11, 33.25, 33.01],
#  'Longitude': [-84.39,
#   -84.41,
#   -84.4112,
#   -84.4201,
#   -84.418,
#   -84.412,
#   -84.415,
#   -84.422]}

# %% [markdown]
# ## Now from here we are plotting the points of Restaurant and its Customers

# %%
import pandas as pd
df3 = pd.DataFrame( data)
# print dataframe.
df3
# Out:
#                   Name  Latitude  Longitude
# 0  Oskar Blues Taproom   33.1700   -84.3900
# 1          Megha Joshi   33.1611   -84.4100
# 2           Ann mariya   33.1620   -84.4112
# 3                Sumar   33.1900   -84.4201
# 4             Sadheesh   33.1200   -84.4180
# 5               Vidhya   33.1100   -84.4120
# 6             Saratoga   33.2500   -84.4150
# 7        Ratnadeep pal   33.0100   -84.4220

# %%
df4=df3
#df4=df4.drop(7,axis=0)

df4["dest1"]=[df3['Latitude'][1],df3['Latitude'][2],df3['Latitude'][3],df3['Latitude'][4],df3['Latitude'][5],df3['Latitude'][6],df3['Latitude'][7],df3['Latitude'][7]]
df4["dest2"]=[df3['Longitude'][1],df3['Longitude'][2],df3['Longitude'][3],df3['Longitude'][4],df3['Longitude'][5],df3['Longitude'][6],df3['Longitude'][7],df3['Longitude'][7]]
df4
# Out:
#                   Name  Latitude  Longitude    dest1    dest2
# 0  Oskar Blues Taproom   33.1700   -84.3900  33.1611 -84.4100
# 1          Megha Joshi   33.1611   -84.4100  33.1620 -84.4112
# 2           Ann mariya   33.1620   -84.4112  33.1900 -84.4201
# 3                Sumar   33.1900   -84.4201  33.1200 -84.4180
# 4             Sadheesh   33.1200   -84.4180  33.1100 -84.4120
# 5               Vidhya   33.1100   -84.4120  33.2500 -84.4150
# 6             Saratoga   33.2500   -84.4150  33.0100 -84.4220
# 7        Ratnadeep pal   33.0100   -84.4220  33.0100 -84.4220

# %%
import openrouteservice
import folium
import pandas as pd
from folium import plugins


m=folium.Map(location=[33.17, -84.39],zoom_start=10)
folium.Marker([33.17, -84.39],popup='Oskar Blues Taproom',tooltip='click').add_to(m)

folium.raster_layers.TileLayer('Open Street Map').add_to(m)
folium.raster_layers.TileLayer('CartoDB Dark_Matter').add_to(m)

Client=openrouteservice.Client(key='5b3ce3597851110001cf6248f8eb202100d142389464c251a0593b9e')

for index,row in df4.iterrows():
    
    route_location = []
    c=[[row['dest2'],row['dest1']],[row['Longitude'],row['Latitude']]]
     
    r= Client.directions(coordinates=c, profile='driving-car', format='geojson')
  
    for i in r["features"][0]["geometry"]["coordinates"]:
        route_location.append(i[::-1])
    #folium.GeoJson(r,name=row['Name']).add_to(m)
    if index != 0:
        folium.Marker([row['Latitude'],row['Longitude']],popup=row['Name'],icon=folium.Icon(color='purple'),tooltip='click').add_to(m)
    plugins.AntPath(route_location).add_to(m)
    
folium.LayerControl().add_to(m)
folium.LayerControl(position='topright',collapsed=False).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## Experiment

# %%
m=folium.Map(location=[l[0]["geometry"]["coordinates"][1],l[0]["geometry"]["coordinates"][0]],zoom_start=15)
folium.Marker([l[0]["geometry"]["coordinates"][1],l[0]["geometry"]["coordinates"][0]],popup=l[0]["name"],tooltip='click',icon=folium.Icon(color='green')).add_to(m)

folium.Marker([res[0]["latitude"],res[0]["longitude"]],popup=res[0]["name"],tooltip='click',icon=folium.Icon(color='red')).add_to(m)
folium.raster_layers.TileLayer('Open Street Map').add_to(m)
folium.raster_layers.TileLayer('CartoDB Dark_Matter').add_to(m)

Client=openrouteservice.Client(key='5b3ce3597851110001cf6248f8eb202100d142389464c251a0593b9e')
route_location = []
c=[[l[0]["geometry"]["coordinates"][0],l[0]["geometry"]["coordinates"][1]],[res[0]["longitude"],res[0]["latitude"]]]
r= Client.directions(coordinates=c, profile='driving-car', format='geojson')
  
for i in r["features"][0]["geometry"]["coordinates"]:
    route_location.append(i[::-1])
plugins.AntPath(route_location).add_to(m)
folium.LayerControl().add_to(m)
folium.LayerControl(position='topright',collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# import openrouteservice
# import folium
# import pandas as pd
# from folium import plugins


# m=folium.Map(location=[33.17, -84.39],zoom_start=10)
# folium.Marker([33.17, -84.39],popup='Oskar Blues Taproom',tooltip='click').add_to(m)

# folium.raster_layers.TileLayer('Open Street Map').add_to(m)
# folium.raster_layers.TileLayer('CartoDB Dark_Matter').add_to(m)

# Client=openrouteservice.Client(key='5b3ce3597851110001cf6248f8eb202100d142389464c251a0593b9e')

for index,row in df4.iterrows():
    
    route_location = []
    c=[[row['Longitude'],row['Latitude']],[row['dest2'],row['dest1']]]
     
    r= Client.directions(coordinates=c, profile='driving-car', format='geojson')
  
    for i in r["features"][0]["geometry"]["coordinates"]:
        route_location.append(i[::-1])
    #folium.GeoJson(r,name=row['Name']).add_to(m)
    if index != 0:
        folium.Marker([row['Latitude'],row['Longitude']],popup=row['Name'],icon=folium.Icon(color='purple'),tooltip='click').add_to(m)
    plugins.AntPath(route_location).add_to(m)
    
# folium.LayerControl().add_to(m)
# folium.LayerControl(position='topright',collapsed=False).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
